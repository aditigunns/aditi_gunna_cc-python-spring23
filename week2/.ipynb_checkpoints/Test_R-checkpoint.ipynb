# %%
txt = "Hello Sam!"
mytable = txt.maketrans("S", "🍅")
mytable1 = txt.maketrans("S", "H")
minetable = txt.maketrans("H", "❄")
print(txt.translate(mytable))
print(txt.translate(mytable1))
print(txt.translate(minetable))
# Out:
# Hello 🍅am!
# Hello Ham!
# ❄ello Sam!

# %%
a = "tomato"
t_to_p = {84: 80, 109:116}
print((a.capitalize()).translate(t_to_p))
# Out:
# Potato

# %%
t = 'tomato'
s = 'sometimes'
n = 'never'
tba = 'To be a'
b = 'but'
m = 'maybe'
u = 'unless'
w = 'would'
w_n = w.replace('w','sh') #changing would to should
emoji = '🍅 '
brk = '\n'
do = { 1 :['red or green','blue or white','painted'], 2 : ['soft with strong skin','hard with a thin peel','frozen'], 3: ['on a plant','on a hanger','hung'], 4 : ['unloved','with potatoes','burnt'] }
#^^ a dictionary with all the different phrases in each stanza
t_to_p = {84: 80, 109:116} #to change tomato to potato
print(brk)
print(t.upper())
print(f'By a cold {t.capitalize()}')
print(brk)
print(emoji*20)
print(brk)
print(f'{tba} {t}, {s} {do[1][0]}')
print(f'{b.capitalize()} {n} {do[1][1]}')
print(f'{u.capitalize()} {do[1][2]}')
print(f'{b.capitalize()} who {w}?')
print(f'{m.capitalize()} I {w_n}')
print(brk*2)
print(f'{tba} {t}, {s} {do[2][0]}')
print(f'{b.capitalize()} {n} {do[2][1]}')
print(f'{u.capitalize()} {do[2][2]}')
print(f'{b.capitalize()} who {w}?')
print(f'{m.capitalize()} I {w_n}')
print(brk*2)
print(f'{tba} {t}, {s} {do[3][0]}')
print(f'{b.capitalize()} {n} {do[3][1]}')
print(f'{u.capitalize()} {do[3][2]}')
print(f'{b.capitalize()} who {w}?')
print(f'{m.capitalize()} I {w_n}')
print(brk*2)
print(f'{tba} {t}, {s} {do[4][0]}')
print(f'{b.capitalize()} {n} {do[4][1]}')
print(f'{u.capitalize()} {do[4][2]}')
print(f'{b.capitalize()} who {w}?')
print(f'{m.capitalize()} I {w_n}')
print(brk*2)
print(f'{tba} {t},')
print(f'{do[1][2]}, {do[2][2]}, {do[3][2]}, {do[4][2]}')
print(f'By a cold {t.capitalize()}')
print(f'{s.capitalize()} a {(t.capitalize()).translate(t_to_p)}')
# Out:
# TOMATO
# By a cold Tomato
#
#
# 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅
#
#
# To be a tomato, sometimes red or green
# But never blue or white
# Unless painted
# But who would?
# Maybe I should
#
#
#
# To be a tomato, sometimes soft with strong skin
# But never hard with a thin peel
# Unless frozen
# But who would?
# Maybe I should
#
#
#
# To be a tomato, sometimes on a plant
# But never on a hanger
# Unless hung
# But who would?
# Maybe I should
#
#
#
# To be a tomato, sometimes unloved
# But never with potatoes
# Unless burnt
# But who would?
# Maybe I should
#
#
#
# To be a tomato,
# painted, frozen, hung, burnt
# By a cold Tomato
# Sometimes a Potato

# %%
t = 'tomato'
s = 'sometimes'
n = 'never'
tba = 'To be a'
b = 'but'
m = 'maybe'
u = 'unless'
w = 'would'
w_n = w.replace('w','sh') #changing would to should
emoji = '🍅 '
brk = '\n'
do = { 1 :['red or green','blue or white','painted'], 2 : ['soft with strong skin','hard with a thin peel','frozen'], 3: ['on a plant','on a hanger','hung'], 4 : ['unloved','with potatoes','burnt'] }
#^^ a dictionary with all the different phrases in each stanza
no = [1,2,3,4] #a list for the loop to run through with the order of the dictionary keys
t_to_p = {84: 80, 109:116} #to change tomato to potato
print(brk)
print(t.upper())
print(f'By a cold {t.capitalize()}')
print(brk)
print(emoji*20)
print(brk)
for x in no:
    print(f'{tba} {t}, {s} {do[x][0]}')
    print(f'{b.capitalize()} {n} {do[x][1]}')
    print(f'{u.capitalize()} {do[x][2]}')
    print(f'{b.capitalize()} who {w}?')
    print(f'{m.capitalize()} I {w_n}')
    print(brk*2)
print(f'{tba} {t},')
print(f'{do[1][2]}, {do[2][2]}, {do[3][2]}, {do[4][2]}')
print(f'By a cold {t.capitalize()}')
t_to_p = {84: 80, 109:116}
print(f'{s.capitalize()} a {(t.capitalize()).translate(t_to_p)}')
# Out:
# TOMATO
# By a cold Tomato
#
#
# 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅 🍅
#
#
# To be a tomato, sometimes red or green
# But never blue or white
# Unless painted
# But who would?
# Maybe I should
#
#
#
# To be a tomato, sometimes soft with strong skin
# But never hard with a thin peel
# Unless frozen
# But who would?
# Maybe I should
#
#
#
# To be a tomato, sometimes on a plant
# But never on a hanger
# Unless hung
# But who would?
# Maybe I should
#
#
#
# To be a tomato, sometimes unloved
# But never with potatoes
# Unless burnt
# But who would?
# Maybe I should
#
#
#
# To be a tomato,
# painted, frozen, hung, burnt
# By a cold Tomato
# Sometimes a Potato
